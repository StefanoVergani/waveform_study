# %%
from PyPurityTools import PyPurityTools as ppt
from PyPurityFunctions import PyPurityFunctions as ppf
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.signal import savgol_filter
import matplotlib.style
import matplotlib as mpl
import math
import scipy.fftpack
from scipy.signal import butter,filtfilt
import scipy.fftpack
import os
import statistics

# %%
path_dir: str = r"/unix/dune/purity/2022October14Vacuum/Gold/"

# %%
#I now extract one single waveform to study it
waveList_ch3 = ppf.single_waveform_check(path_dir,"Field_5.10.20Vcm_FibreIn_",".ch3.traces")

# %%
#Set default figure size
mpl.rcParams['figure.figsize'] = [12.0, 8.0]
mpl.rcParams["legend.frameon"] = False
mpl.rcParams.update({'font.size': 22})

# %%
ch3_time=np.arange(len(waveList_ch3[0]))

# %%
fig, ax = plt.subplots()
ax.plot(ch3_time,waveList_ch3[0],label="Input Pulse")
ax.set_xlabel("Measurement [a.u.]")
ax.set_ylabel("Voltage [Volts]")
ax.set_title("A waveform for channel 3")
# Out:
# Text(0.5,1,'A waveform for channel 3')

# %%
bkg_waveform = ppf.single_waveform_check(path_dir,"Field_5.10.20Vcm_FibreOut_HVOn",".ch3.traces")

# %%
len(bkg_waveform)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0a64e4b6fdd8> in <module>()
# ----> 1 len(bkg_waveform)
#
# TypeError: object of type 'NoneType' has no len()
